# %% [markdown]
# # importing libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
import seaborn as sns

# %% [markdown]
# # Loading DataSet

# %%
df = pd.read_excel('Dataset_w6.xlsx')

# %% [markdown]
# # 1. No. of countries in the data set

# %%
d1 = df['country'].count()
print(d1)
# Out:
# 196

# %% [markdown]
# # 2. No. countries w.r.t regions

# %%
unique_regions = df.groupby('Region')['country'].nunique()
print(unique_regions)
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %% [markdown]
# # 3.a Highest GDP per capita

# %%
data1 = pd.DataFrame(df.groupby(['Region'])['GDP per capita (current US$)'].mean())
print(data1[data1['GDP per capita (current US$)'] == data1['GDP per capita (current US$)'].max()])
# Out:
#                  GDP per capita (current US$)
# Region
# NorthernAmerica                       57659.0

# %% [markdown]
# # 3.b Highest international trade per imports

# %%
data2 = pd.DataFrame(df.groupby(['Region'])['International trade: Imports (million US$)'].mean())
print(data2[data2['International trade: Imports (million US$)'] == data2['International trade: Imports (million US$)'].max()])
# Out:
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                                   663552.25

# %% [markdown]
# # 4. Consistent region by per capita

# %%
r = 100000
s = []
for key, item in gp:
    p = gp.get_group(key)
    q = np.std(p['GDP per capita (current US$)'].to_numpy())
    if q < r :
        r = q
        s = p['Region']
print(s[:1])

gp = df.groupby('Region')[['GDP per capita (current US$)','Region']]
u = gp.std()
u.sort_values(by = ['GDP per capita (current US$)'],axis=0, ascending = True, )
# Out:
# 17    WesternAfrica
# Name: Region, dtype: object
#                    GDP per capita (current US$)
# Region
# WesternAfrica                        815.095399
# NorthernAfrica                       974.706575
# SouthernAfrica                      2177.551120
# SouthernAsia                        2855.708179
# EasternAfrica                       3716.131770
# CentralAsia                         4152.215490
# CentralAmerica                      4180.440883
# SouthAmerica                        4273.707394
# Micronesia                          4820.669694
# MiddleAfrica                        5274.846281
# EasternEurope                       5415.488739
# Polynesia                           6956.250286
# Oceania                             9233.329638
# SouthernEurope                      9541.703216
# Melanesia                          13855.842686
# Caribbean                          14579.371326
# South-easternAsia                  16311.810656
# ...
